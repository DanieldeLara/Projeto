# %% [markdown]
# <h1>Venda de jogos de videogames na História</h1>
# <br>
# Este projeto foi criado por <b>Daniel de Lara</b>. Aqui eu irei realizar algumas análises sobre os dados encontrados <a hrfe='https://www.kaggle.com/kendallgillies/video-game-sales-and-ratings'>neste dataset</a>.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
#Leitura do arquivo
videogames = pd.read_csv('Video_Game_Sales.csv')

# %%
#Exibindo as 10 primeiras linhas do Dataframe
videogames.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue        G           1996.0  Role-Playing
# 5                     Tetris        G           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.54
# ...

# %%
#Resumo das informações em todas as colunas
videogames.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     17408.000000  17416.000000  17416.000000  17416.000000
# mean       2006.630859      0.254534      0.140727      0.075020
# std           5.901598      0.800673      0.497341      0.303412
# min        1976.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2008.000000      0.070000      0.020000      0.000000
# 75%        2011.000000      0.230000      0.100000      0.030000
# max        2017.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  17416.000000  17416.000000   8336.000000   8336.000000  7798.000000
# mean       0.045908      0.516469     68.912548     26.192059     7.117056
# std        0.183932      1.526124     13.964937     18.991526     1.502410
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# ...

# %%
#Tipos de dados em cada coluna
videogames.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Rating              object
# dtype: object

# %%
#Quantidade de dados em cada coluna
videogames.shape
# Out:
# (17416, 15)

# %%
#Renomendo colunas
videogames.columns = ['Nome', 'Plataforma', 'Ano', 'Gênero', 'Editora', 'Vendas América do Norte', 'Vendas EUA', 'Vendas Japão', 'Outras Vendas', 'Vendas Global', 'Pontuação Crítica', 'Contagem Crítica', 'Pontuação Usuário', 'Contagem Usuários', 'Classificação']

# %%
#Exibindo as 10 primeiras linhas do arquivo
videogames.head(10)
# Out:
#                         Nome Plataforma     Ano        Gênero   Editora  \
# 0                 Wii Sports        Wii  2006.0        Sports  Nintendo
# 1          Super Mario Bros.        NES  1985.0      Platform  Nintendo
# 2             Mario Kart Wii        Wii  2008.0        Racing  Nintendo
# 3          Wii Sports Resort        Wii  2009.0        Sports  Nintendo
# 4   Pokemon Red/Pokemon Blue          G  1996.0  Role-Playing  Nintendo
# 5                     Tetris          G  1989.0        Puzzle  Nintendo
# 6      New Super Mario Bros.         DS  2006.0      Platform  Nintendo
# 7                   Wii Play        Wii  2006.0          Misc  Nintendo
# 8  New Super Mario Bros. Wii        Wii  2009.0      Platform  Nintendo
# 9                  Duck Hunt        NES  1984.0       Shooter  Nintendo
#
#    Vendas América do Norte  Vendas EUA  Vendas Japão  Outras Vendas  \
# 0                    41.36       28.96          3.77           8.45
# ...

# %%
#Verificando limhas onde não há ano de lançamento definida
videogames[videogames['Ano'].isnull()].head()
# Out:
#                                              Nome Plataforma  Ano      Gênero  \
# 12795                Mobile Ops: The One Year War       X360  NaN  Simulation
# 14210                                Housekeeping         DS  NaN      Action
# 14532            Fullmetal Alchemist: Brotherhood        PSP  NaN      Action
# 15162                 Wii de Asobu: Metroid Prime        Wii  NaN     Shooter
# 15784  Writing and Speaking Beautiful Japanese DS         DS  NaN        Misc
#
#                   Editora  Vendas América do Norte  Vendas EUA  Vendas Japão  \
# 12795  Namco Bandai Games                      0.0         0.0          0.06
# 14210             Unknown                      0.0         0.0          0.04
# 14532             Unknown                      0.0         0.0          0.03
# 15162            Nintendo                      0.0         0.0          0.02
# 15784             Unknown                      0.0         0.0          0.02
#
# ...

# %%
#Contagem de jogos por plataforma
videogames['Plataforma'].value_counts()
# Out:
# DS      2251
# PS2     2206
# PS3     1362
# Wii     1359
# PSP     1304
# X360    1298
# PS      1200
# PC      1128
# GBA      844
# X        833
# GC       563
# 3DS      553
# PSV      503
# PS4      424
# N64      319
# XOne     264
# SNES     239
# SAT      173
# WiiU     153
# 2600     133
# G         98
# NES       98
# DC        52
# GEN       27
# NG        12
# WS         7
# SCD        6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Plataforma, dtype: int64

# %%
#Os dois pedaços de código abaixo fazem a mesma coisa
titulos_lancados = videogames['Plataforma'].value_counts()
titulos_lancados.plot()

videogames['Plataforma'].value_counts().plot()

# %%
#Criando um gráfico utilizando apenas uma linha de código
videogames['Plataforma'].value_counts().head(10).plot(kind = 'bar', figsize = (11,5), grid = False, rot = 0, color = 'gray' )

#apromorando gráfico definindo título
plt.title('Os dez videogames com mais títulos lançados')
plt.xlabel('Videogame')
plt.ylabel('Qtde de jogos lançados')
plt.show()

# %%
#Os 10 jogos mais vendidos da história
top_10_vendidos = videogames[['Nome', 'Vendas Global']].head(10).set_index('Nome').sort_values('Vendas Global', ascending = True)
top_10_vendidos.plot(kind = 'barh', figsize = (11,7), grid = False, color = 'darkred', legend = False)

plt.title('Os dez jogos mais vendidos no mundo')
plt.xlabel('Total de vendas (em milhões de dolares)')
plt.ylabel('Nome')
plt.show()

# %%
#Informações cruzadas
crosstab_vg = pd.crosstab(videogames['Plataforma'],videogames['Gênero'])
crosstab_vg.head()
# Out:
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            201         40        15    59        29      23      11
# DC               3         11        12     0         2       0       6
# DS             350        261        37   403        92     249      70
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy
# Plataforma
# 2600                   0       24           1      12         0
# 3DO                    0        0           1       0         0
# 3DS                   91        7          32      27        18
# DC                     4        3           1      10         0
# DS                   209       42         304     153        81

# %%
#Adicionar coluna Total
crosstab_vg['Total'] = crosstab_vg.sum(axis = 1)
crosstab_vg.head()
# Out:
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            201         40        15    59        29      23      11
# DC               3         11        12     0         2       0       6
# DS             350        261        37   403        92     249      70
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy  Total
# Plataforma
# 2600                   0       24           1      12         0    133
# 3DO                    0        0           1       0         0      3
# 3DS                   91        7          32      27        18    553
# DC                     4        3           1      10         0     52
# DS                   209       42         304     153        81   2251

# %%
#Gráfico de calor
top_10_Plataforma = crosstab_vg[crosstab_vg['Total'] > 1000].sort_values('Total', ascending = False)
top_10_final = top_10_Plataforma.append(pd.DataFrame(top_10_Plataforma.sum(), columns = ['TOTAL']).T, ignore_index = False)

sns.set(font_scale = 1)
plt.figure(figsize = (18,9))
sns.heatmap(top_10_final, annot = True, vmax = top_10_final.loc[:'PS', :'Strategy'].values.max(), vmin = top_10_final.loc[:, :'strategy'].values.min(), fmt = 'd')
plt.xlabel('GÊNERO')
plt.ylabel('CONSOLE')
plt.title('QUANTIDADE DE TÍTULOS POR GÊNERO E CONSOLE')
plt.show()
